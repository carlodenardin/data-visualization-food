# %%
'''
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.axes as ax
import seaborn as sns
import plotly as py 
import plotly.graph_objs as go
import scipy.cluster.hierarchy as shc
from plotly.offline import init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
from sklearn.cluster import KMeans, AgglomerativeClustering, AffinityPropagation
from sklearn.preprocessing import StandardScaler
import os
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
'''
# Out:
# '\nimport numpy as np \nimport pandas as pd \nimport matplotlib.pyplot as plt\nimport matplotlib.axes as ax\nimport seaborn as sns\nimport plotly as py \nimport plotly.graph_objs as go\nimport scipy.cluster.hierarchy as shc\nfrom plotly.offline import init_notebook_mode, plot, iplot\ninit_notebook_mode(connected=True)\nfrom sklearn.cluster import KMeans, AgglomerativeClustering, AffinityPropagation\nfrom sklearn.preprocessing import StandardScaler\nimport os\nfrom PIL import Image\nfrom wordcloud import WordCloud, STOPWORDS, ImageColorGenerator\n'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# %%
# Import common styles
# %run ../common_styles.ipynb

# %%
# Setting font
font_dirs = ['Cabin/']
font_files = font_manager.findSystemFonts(fontpaths = font_dirs)

for font_file in font_files:
    font_manager.fontManager.addfont(font_file)

plt.rcParams['font.family'] = FONT_STYLE

# %%
# Useful functions
def millions_formatter(x, pos):
    return f'{x / 100000:.1f}'

# %%
df = pd.read_csv("top10world.csv").iloc[:20 ,:]
df = df.sort_values(by=['Value'], ascending = True)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15, 8)
fig.patch.set_facecolor(BACKGROUND_COLOR)

# Plot
plt.hlines(y = my_range,  xmin = 0, xmax = df.Value, color = BAR_COLOR[0], linestyles='solid', linewidth = 3)
plt.plot(df.Value, my_range, "o", markersize = 12, color = BAR_COLOR[1], markeredgecolor = BAR_COLOR[0], markeredgewidth = 2)

# X AXIS
x_ticks = np.arange(0, 900000, 50000)
ax.set_xticks(x_ticks)
ax.set_xlabel('Value (million tonnes)', fontsize = LABEL_SIZE, fontweight = LABEL_WEIGHT, labelpad = LABEL_PAD, color = PRIMARY_TEXT_COLOR)
ax.xaxis.set_major_formatter(FuncFormatter(millions_formatter))

# Y AXIS
ax.set_ylabel('Types of food', fontsize = LABEL_SIZE, fontweight = LABEL_WEIGHT, labelpad = LABEL_PAD, color = PRIMARY_TEXT_COLOR)
ax.set_xlim(0, 860000)
ax.set_yticks(my_range)
ax.yaxis.set_ticks_position('none')
ax.set_yticklabels(df.Item, fontsize = TICK_SIZE, color = PRIMARY_TEXT_COLOR)

# TICK PARAMETERS
ax.tick_params(axis = 'both', which = 'major', labelsize = TICK_SIZE, color = PRIMARY_TEXT_COLOR)

# AXIS
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_linewidth(0.5)
ax.spines['bottom'].set_linewidth(0.5)

# TICK PARAMETERS
ax.tick_params(axis = 'both', which = 'major', labelsize = TICK_SIZE, color = PRIMARY_TEXT_COLOR)

# GRID
ax.set_axisbelow(True)
ax.xaxis.grid(True, color = GRID_COLOR, linestyle = '--', dashes=(5, 6), linewidth = 0.5)

# Set face color
ax.set_facecolor(BACKGROUND_COLOR)

plt.tight_layout()

plt.savefig('top20.png', dpi = 1200, bbox_inches = 'tight')
plt.show()

# %%
fig, ax = plt.subplot_mosaic(
    [
        ['main', 'title', 'title'],
        ['main', 'title', 'note'],
        ['main', 'note', 'note'],
    ],
    figsize = (15, 8),
    layout = "constrained",
    gridspec_kw = {'width_ratios': [3, 0.5, 0.5]}
)
fig.patch.set_facecolor(BACKGROUND_COLOR)

# Plot
plt.hlines(y = my_range,  xmin = 0, xmax = df.Value, color = BAR_COLOR[0], linestyles='solid', linewidth = 3)
plt.plot(df.Value, my_range, "o", markersize = 12, color = BAR_COLOR[1], markeredgecolor = BAR_COLOR[0], markeredgewidth = 2)

# X AXIS
x_ticks = np.arange(0, 900000, 50000)
ax.set_xticks(x_ticks)
ax.set_xlabel('Value (million tonnes)', fontsize = LABEL_SIZE, fontweight = LABEL_WEIGHT, labelpad = LABEL_PAD, color = PRIMARY_TEXT_COLOR)
ax.xaxis.set_major_formatter(FuncFormatter(millions_formatter))

# Y AXIS
ax.set_ylabel('Types of food', fontsize = LABEL_SIZE, fontweight = LABEL_WEIGHT, labelpad = LABEL_PAD, color = PRIMARY_TEXT_COLOR)
ax.set_xlim(0, 860000)
ax.set_yticks(my_range)
ax.yaxis.set_ticks_position('none')
ax.set_yticklabels(df.Item, fontsize = TICK_SIZE, color = PRIMARY_TEXT_COLOR)

# TICK PARAMETERS
ax.tick_params(axis = 'both', which = 'major', labelsize = TICK_SIZE, color = PRIMARY_TEXT_COLOR)

# AXIS
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_linewidth(0.5)
ax.spines['bottom'].set_linewidth(0.5)

# TICK PARAMETERS
ax.tick_params(axis = 'both', which = 'major', labelsize = TICK_SIZE, color = PRIMARY_TEXT_COLOR)

# GRID
ax.set_axisbelow(True)
ax.xaxis.grid(True, color = GRID_COLOR, linestyle = '--', dashes=(5, 6), linewidth = 0.5)

# Set face color
ax.set_facecolor(BACKGROUND_COLOR)

# Save figure with 1200 dpi
plt.savefig('top20.png', dpi = 1200, bbox_inches = 'tight')
plt.show()
